# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine
from urllib.parse import quote_plus

# Encode password safely because it contains '@'
password = quote_plus("Abhi@1445")

# Create SQLAlchemy engine
engine = create_engine(
    f"mysql+mysqlconnector://root:{password}@localhost/tcg_market_analysis"
)

# Reusable SQL function
def sql(query):
    return pd.read_sql(query, engine)

print("Connected ✅")
# Out:
# Connected ✅

# %%
# This documents WHY each table is needed
# This is what you would present to the tech team

schema_plan = {
    "schema_calls": {
        "purpose": "Track every Exotel call with AI summary status",
        "critical_columns": ["call_duration_sec", "ai_summary_status", "pair_score"],
        "enables_analysis": "Call quality, AI failure rate, score validation"
    },
    "schema_leads": {
        "purpose": "Track every lead through the sales funnel",
        "critical_columns": ["lead_source", "stage", "budget", "final_outcome"],
        "enables_analysis": "Funnel analysis, source performance, conversion rates"
    },
    "schema_user_logins": {
        "purpose": "Track platform login activity per client",
        "critical_columns": ["client_id", "login_time"],
        "enables_analysis": "Churn risk detection, DAU/MAU tracking"
    },
    "schema_feature_logs": {
        "purpose": "Track which features clients use inside the platform",
        "critical_columns": ["module", "feature_name"],
        "enables_analysis": "Feature adoption, low-usage client flagging"
    }
}

for table, info in schema_plan.items():
    print(f"\n{'='*50}")
    print(f"TABLE: {table}")
    print(f"Purpose:   {info['purpose']}")
    print(f"Key cols:  {', '.join(info['critical_columns'])}")
    print(f"Enables:   {info['enables_analysis']}")
# Out:
# ...
# TABLE: schema_calls
# Purpose:   Track every Exotel call with AI summary status
# Key cols:  call_duration_sec, ai_summary_status, pair_score
# Enables:   Call quality, AI failure rate, score validation
#
# ...
# TABLE: schema_leads
# Purpose:   Track every lead through the sales funnel
# Key cols:  lead_source, stage, budget, final_outcome
# Enables:   Funnel analysis, source performance, conversion rates
#
# ...
# TABLE: schema_user_logins
# Purpose:   Track platform login activity per client
# Key cols:  client_id, login_time
# Enables:   Churn risk detection, DAU/MAU tracking
#
# ...
# TABLE: schema_feature_logs
# Purpose:   Track which features clients use inside the platform
# Key cols:  module, feature_name
# Enables:   Feature adoption, low-usage client flagging
